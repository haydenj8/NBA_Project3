# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import make_column_selector, make_column_transformer

# %%
players = pd.read_csv('data/Players.csv')
players = players.drop(columns= ['Unnamed: 0'], axis=1)
players
# Out:
#                  Player  height  weight                          collage  \
# 0       Curly Armstrong   180.0    77.0               Indiana University
# 1          Cliff Barker   188.0    83.0           University of Kentucky
# 2         Leo Barnhorst   193.0    86.0         University of Notre Dame
# 3            Ed Bartels   196.0    88.0  North Carolina State University
# 4           Ralph Beard   178.0    79.0           University of Kentucky
# ...                 ...     ...     ...                              ...
# 3917      Troy Williams   198.0    97.0  South Carolina State University
# 3918       Kyle Wiltjer   208.0   108.0               Gonzaga University
# 3919  Stephen Zimmerman   213.0   108.0  University of Nevada, Las Vegas
# 3920        Paul Zipser   203.0    97.0                              NaN
# 3921        Ivica Zubac   216.0   120.0                              NaN
#
#         born      birth_city             birth_state
# 0     1918.0             NaN                     NaN
# 1     1921.0        Yorktown                 Indiana
# 2     1924.0             NaN                     NaN
# 3     1925.0             NaN                     NaN
# 4     1927.0     Hardinsburg                Kentucky
# ...      ...             ...                     ...
# 3917  1969.0        Columbia          South Carolina
# 3918  1992.0        Portland                  Oregon
# 3919  1996.0  Hendersonville               Tennessee
# 3920  1994.0      Heidelberg                 Germany
# 3921  1997.0          Mostar  Bosnia and Herzegovina
#
# [3922 rows x 7 columns]

# %%
stats = pd.read_csv('data/Seasons_Stats.csv')
stats = stats.drop(columns= ['Unnamed: 0'], axis=1)
stats
# Out:
#          Year             Player  Pos   Age   Tm     G    GS      MP   PER  \
# 0      1950.0    Curly Armstrong  G-F  31.0  FTW  63.0   NaN     NaN   NaN
# 1      1950.0       Cliff Barker   SG  29.0  INO  49.0   NaN     NaN   NaN
# 2      1950.0      Leo Barnhorst   SF  25.0  CHS  67.0   NaN     NaN   NaN
# 3      1950.0         Ed Bartels    F  24.0  TOT  15.0   NaN     NaN   NaN
# 4      1950.0         Ed Bartels    F  24.0  DNN  13.0   NaN     NaN   NaN
# ...       ...                ...  ...   ...  ...   ...   ...     ...   ...
# 24686  2017.0        Cody Zeller   PF  24.0  CHO  62.0  58.0  1725.0  16.7
# 24687  2017.0       Tyler Zeller    C  27.0  BOS  51.0   5.0   525.0  13.0
# 24688  2017.0  Stephen Zimmerman    C  20.0  ORL  19.0   0.0   108.0   7.3
# 24689  2017.0        Paul Zipser   SF  22.0  CHI  44.0  18.0   843.0   6.9
# 24690  2017.0        Ivica Zubac    C  19.0  LAL  38.0  11.0   609.0  17.0
#
#          TS%  ...    FT%    ORB    DRB    TRB    AST   STL   BLK   TOV     PF  \
# 0      0.368  ...  0.705    NaN    NaN    NaN  176.0   NaN   NaN   NaN  217.0
# 1      0.435  ...  0.708    NaN    NaN    NaN  109.0   NaN   NaN   NaN   99.0
# 2      0.394  ...  0.698    NaN    NaN    NaN  140.0   NaN   NaN   NaN  192.0
# 3      0.312  ...  0.559    NaN    NaN    NaN   20.0   NaN   NaN   NaN   29.0
# 4      0.308  ...  0.548    NaN    NaN    NaN   20.0   NaN   NaN   NaN   27.0
# ...      ...  ...    ...    ...    ...    ...    ...   ...   ...   ...    ...
# 24686  0.604  ...  0.679  135.0  270.0  405.0   99.0  62.0  58.0  65.0  189.0
# 24687  0.508  ...  0.564   43.0   81.0  124.0   42.0   7.0  21.0  20.0   61.0
# 24688  0.346  ...  0.600   11.0   24.0   35.0    4.0   2.0   5.0   3.0   17.0
# 24689  0.503  ...  0.775   15.0  110.0  125.0   36.0  15.0  16.0  40.0   78.0
# 24690  0.547  ...  0.653   41.0  118.0  159.0   30.0  14.0  33.0  30.0   66.0
#
#          PTS
# 0      458.0
# 1      279.0
# 2      438.0
# 3       63.0
# 4       59.0
# ...      ...
# 24686  639.0
# 24687  178.0
# 24688   23.0
# 24689  240.0
# 24690  284.0
#
# [24691 rows x 52 columns]

# %%
stats.loc[stats.index == 'Michael Jordan*']
# Out:
# Empty DataFrame
# Columns: [Year, Player, Pos, Age, Tm, G, GS, MP, PER, TS%, 3PAr, FTr, ORB%, DRB%, TRB%, AST%, STL%, BLK%, TOV%, USG%, blanl, OWS, DWS, WS, WS/48, blank2, OBPM, DBPM, BPM, VORP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS]
# Index: []
#
# [0 rows x 52 columns]

# %%
mvp_players = {'Bob Pettit*': [1956, 1959],
                  'Bob Cousy*': [1957],
                  'Bill Russell*': [1958, 1961, 1962, 1963, 1965],
                  'Wilt Chamberlain*': [1960, 1966, 1967, 1968],
                  'Oscar Robertson*': [1964],
                  'Wes Unseld*': [1969],
                  'Willis Reed*': [1970],
                  'Kareem Abdul-Jabbar*': [1971, 1972, 1974, 1976, 1977, 1980],
                  'Dave Cowens*': [1973],
                  'Bob McAdoo*': [1975],
                  'Bill Walton*': [1978],
                  'Moses Malone*': [1979, 1982, 1983],
                  'Julius Erving*': [1981],
                  'Larry Bird*': [1984, 1985, 1986],
                  'Magic Johnson*': [1987, 1989, 1990],
                  'Michael Jordan*': [1988, 1991, 1992, 1996, 1998],
                  'Charles Barkley*': [1993],
                  'Hakeem Olajuwon*': [1994],
                  'David Robinson*': [1995],
                  'Karl Malone*': [1997, 1999],
                  'Shaquille O\'Neal*': [2000],
                  'Allen Iverson*': [2001],
                  'Tim Duncan': [2002, 2003],
                  'Kevin Garnett': [2004],
                  'Steve Nash': [2005, 2006],
                  'Dirk Nowitzki': [2007],
                  'Kobe Bryant': [2008],
                  'LeBron James': [2009, 2010, 2012, 2013],
                  'Derrick Rose': [2011],
                  'Kevin Durant': [2014],
                  'Stephen Curry': [2015, 2016],
                  'Russell Westbrook': [2017],
                  'James Harden': [2018]}

# %%
stats['MVP'] = 0
for i, row in stats.iterrows():
    for k, v in mvp_players.items():
        for year in v:
            if row['Player'] != k:
                break
            elif(row['Year'] == year) & (row['Player'] == k):
                stats.loc[i, 'MVP'] = 1
                break

# %%
teams_champions = {'BOS': [1957, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1968, 1969, 1974, 1976, 1981, 1984, 1986, 2008],
                  'LAL': [1972, 1980, 1982, 1985, 1987, 1988, 2000, 2001, 2002, 2009, 2010],
                  'MNL': [1949, 1950, 1952, 1953, 1954],
                  'CHI': [1991, 1992, 1993, 1996, 1997, 1998],
                  'GSW': [1975, 2015, 2017, 2018],
                  'PHW': [1947, 1956],
                  'SAS': [1999, 2003, 2005, 2007, 2014],
                  'DET': [1989, 1990, 2004],
                  'MIA': [2006, 2012, 2013],
                  'PHI': [1967, 1983],
                  'SYR': [1955],
                  'HOU': [1994, 1995],
                  'NYK': [1970, 1973],
                  'STL': [1958],
                  'BLB': [1948],
                  'CLE': [2016],
                  'DAL': [2011],
                  'MIL': [1971],
                  'SEA': [1979],
                  'POR': [1977],
                  'ROC': [1951],
                  'WSB': [1978]}

# %%
stats['rings'] = 0
for i, row in stats.iterrows():
    for k, v in teams_champions.items():
        for year in v:
            if row['Tm'] != k:
                break
            elif(row['Year'] == year) & (row['Tm'] == k):
                stats.loc[i, 'rings'] = 1
                break

# %%
finals_mvp = {'Jerry West*': [1969],
               'Willis Reed*': [1970, 1973],
               'Micheal Jordan*': [1991, 1992, 1993, 1996, 1997, 1998],
               'Lebron James*': [2012, 2013, 2016],
                 'Magic Johnson*': [1980, 1982, 1987],
                 'Shaquille O\'Neal*': [2000, 2001, 2002],
                 'Tim Duncan': [1999, 2003, 2005],
                 'Kareem Abdul-Jabbar*': [1971, 1985],
                 'Larry Bird*': [1984, 1986],
                 'Hakeem Olajuwon*': [1994, 1995],
                 'Kobe Bryant': [2009, 2010],
                 'Kevin Durant': [2017, 2018],
                 'Kawhi Leonard': [2014], 
                 'Wilt Chamberlain*': [1972],
                 'John Havlicek*': [1974],
                 'Rick Barry': [1975], 
                 'Jo Jo White*': [1976], 
                 'Bill Walton*': [1977],
                 'Wes Unseld*': [1978],
                 'Dennis Johnson*': [1979],
                 'Cedric Maxwell': [1981], 
                 'Moses Malone*': [1983],
                 'James Worthy*': [1988],
                 'Joe Dumars*': [1989],
                 'Isiah Thomas*': [1990],
                 'Chauncey Billups': [2004],
                 'Dwayne Wade': [2006],
                 'Tony Parker': [2007],
                 'Paul Pierce': [2008],
                 'Dirk Nowitzki': [2011],
                 'Andre Iguodala': [2015]}

# %%
stats['finals_mvp'] = 0
for i, row in stats.iterrows():
    for k, v in finals_mvp.items():
        for year in v:
            if row['Player'] != k:
                break
            elif(row['Year'] == year) & (row['Player'] == k):
                stats.loc[i, 'finals_mvp'] = 1
                break

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24691 entries, 0 to 24690
# Data columns (total 55 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        24624 non-null  float64
#  1   Player      24624 non-null  object
#  2   Pos         24624 non-null  object
#  3   Age         24616 non-null  float64
#  4   Tm          24624 non-null  object
#  5   G           24624 non-null  float64
#  6   GS          18233 non-null  float64
#  7   MP          24138 non-null  float64
#  8   PER         24101 non-null  float64
#  9   TS%         24538 non-null  float64
#  10  3PAr        18839 non-null  float64
#  11  FTr         24525 non-null  float64
#  12  ORB%        20792 non-null  float64
#  13  DRB%        20792 non-null  float64
#  14  TRB%        21571 non-null  float64
#  15  AST%        22555 non-null  float64
#  16  STL%        20792 non-null  float64
#  17  BLK%        20792 non-null  float64
#  18  TOV%        19582 non-null  float64
#  19  USG%        19640 non-null  float64
#  20  blanl       0 non-null      float64
#  21  OWS         24585 non-null  float64
#  22  DWS         24585 non-null  float64
#  23  WS          24585 non-null  float64
#  24  WS/48       24101 non-null  float64
#  25  blank2      0 non-null      float64
#  26  OBPM        20797 non-null  float64
#  27  DBPM        20797 non-null  float64
#  28  BPM         20797 non-null  float64
#  29  VORP        20797 non-null  float64
#  30  FG          24624 non-null  float64
#  31  FGA         24624 non-null  float64
#  32  FG%         24525 non-null  float64
#  33  3P          18927 non-null  float64
#  34  3PA         18927 non-null  float64
#  35  3P%         15416 non-null  float64
#  36  2P          24624 non-null  float64
#  37  2PA         24624 non-null  float64
#  38  2P%         24496 non-null  float64
#  39  eFG%        24525 non-null  float64
#  40  FT          24624 non-null  float64
#  41  FTA         24624 non-null  float64
#  42  FT%         23766 non-null  float64
#  43  ORB         20797 non-null  float64
#  44  DRB         20797 non-null  float64
#  45  TRB         24312 non-null  float64
#  46  AST         24624 non-null  float64
#  47  STL         20797 non-null  float64
#  48  BLK         20797 non-null  float64
#  49  TOV         19645 non-null  float64
#  50  PF          24624 non-null  float64
#  51  PTS         24624 non-null  float64
#  52  MVP         24691 non-null  int64
#  53  rings       24691 non-null  int64
#  54  finals_mvp  24691 non-null  int64
# dtypes: float64(49), int64(3), object(3)
# memory usage: 10.4+ MB

# %%
len(stats.Player.unique())
# Out:
# 3922

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24691 entries, 0 to 24690
# Data columns (total 55 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        24624 non-null  float64
#  1   Player      24624 non-null  object
#  2   Pos         24624 non-null  object
#  3   Age         24616 non-null  float64
#  4   Tm          24624 non-null  object
#  5   G           24624 non-null  float64
#  6   GS          18233 non-null  float64
#  7   MP          24138 non-null  float64
#  8   PER         24101 non-null  float64
#  9   TS%         24538 non-null  float64
#  10  3PAr        18839 non-null  float64
#  11  FTr         24525 non-null  float64
#  12  ORB%        20792 non-null  float64
#  13  DRB%        20792 non-null  float64
#  14  TRB%        21571 non-null  float64
#  15  AST%        22555 non-null  float64
#  16  STL%        20792 non-null  float64
#  17  BLK%        20792 non-null  float64
#  18  TOV%        19582 non-null  float64
#  19  USG%        19640 non-null  float64
#  20  blanl       0 non-null      float64
#  21  OWS         24585 non-null  float64
#  22  DWS         24585 non-null  float64
#  23  WS          24585 non-null  float64
#  24  WS/48       24101 non-null  float64
#  25  blank2      0 non-null      float64
#  26  OBPM        20797 non-null  float64
#  27  DBPM        20797 non-null  float64
#  28  BPM         20797 non-null  float64
#  29  VORP        20797 non-null  float64
#  30  FG          24624 non-null  float64
#  31  FGA         24624 non-null  float64
#  32  FG%         24525 non-null  float64
#  33  3P          18927 non-null  float64
#  34  3PA         18927 non-null  float64
#  35  3P%         15416 non-null  float64
#  36  2P          24624 non-null  float64
#  37  2PA         24624 non-null  float64
#  38  2P%         24496 non-null  float64
#  39  eFG%        24525 non-null  float64
#  40  FT          24624 non-null  float64
#  41  FTA         24624 non-null  float64
#  42  FT%         23766 non-null  float64
#  43  ORB         20797 non-null  float64
#  44  DRB         20797 non-null  float64
#  45  TRB         24312 non-null  float64
#  46  AST         24624 non-null  float64
#  47  STL         20797 non-null  float64
#  48  BLK         20797 non-null  float64
#  49  TOV         19645 non-null  float64
#  50  PF          24624 non-null  float64
#  51  PTS         24624 non-null  float64
#  52  MVP         24691 non-null  int64
#  53  rings       24691 non-null  int64
#  54  finals_mvp  24691 non-null  int64
# dtypes: float64(49), int64(3), object(3)
# memory usage: 10.4+ MB

# %%
stats['MVP'].value_counts()
# Out:
# 0    24629
# 1       62
# Name: MVP, dtype: int64

# %%
totals = stats.groupby('Player').count()['Year']
totals = pd.DataFrame(totals)
totals.reset_index(inplace=True)
totals.head()
# Out:
#           Player  Year
# 0     A.C. Green    18
# 1  A.J. Bramlett     1
# 2   A.J. English     2
# 3    A.J. Guyton     3
# 4   A.J. Hammons     1

# %%
totals['Seasons'] = totals['Year']
totals = totals.drop(columns=['Year'], axis=1)

# %%
totals['position'] = stats.Pos

# %%
totals.columns = totals.columns.str.lower()

# %%
totals['team'] = stats.Tm

# %%
games = stats.groupby('Player').sum()['G']
games = pd.DataFrame(games)
games.reset_index(inplace=True)
games.columns = games.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(games, totals, how='left', on='player')
totals.rename(columns= {'g': 'games_played'}, inplace=True)
totals.head()
# Out:
#           player  games_played  seasons position team
# 0     A.C. Green        1361.0       18      G-F  FTW
# 1  A.J. Bramlett           8.0        1       SG  INO
# 2   A.J. English         151.0        2       SF  CHS
# 3    A.J. Guyton          80.0        3        F  TOT
# 4   A.J. Hammons          22.0        1        F  DNN

# %%
player_efficiency = stats.groupby('Player').mean()['PER']
player_efficiency = pd.DataFrame(player_efficiency)
player_efficiency.reset_index(inplace=True)
player_efficiency.columns = player_efficiency.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(player_efficiency, totals, how='left', on='player')
totals.rename(columns = {'per': 'player_efficiency_rating'}, inplace=True)
totals.head()
# Out:
#           player  player_efficiency_rating  games_played  seasons position  \
# 0     A.C. Green                 13.872222        1361.0       18      G-F
# 1  A.J. Bramlett                 -0.400000           8.0        1       SG
# 2   A.J. English                 11.550000         151.0        2       SF
# 3    A.J. Guyton                  4.366667          80.0        3        F
# 4   A.J. Hammons                  8.400000          22.0        1        F
#
#   team
# 0  FTW
# 1  INO
# 2  CHS
# 3  TOT
# 4  DNN

# %%
shooting_percent = stats.groupby('Player').mean()['TS%']
shooting_percent = pd.DataFrame(shooting_percent)
shooting_percent.reset_index(inplace=True)
shooting_percent.columns = shooting_percent.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(shooting_percent, totals, how='left', on='player')
totals.rename(columns = {'ts%': 'shooting_percent'}, inplace=True)
totals.head()
# Out:
#           player  shooting_percent  player_efficiency_rating  games_played  \
# 0     A.C. Green          0.543556                 13.872222        1361.0
# 1  A.J. Bramlett          0.190000                 -0.400000           8.0
# 2   A.J. English          0.480000                 11.550000         151.0
# 3    A.J. Guyton          0.324000                  4.366667          80.0
# 4   A.J. Hammons          0.472000                  8.400000          22.0
#
#    seasons position team
# 0       18      G-F  FTW
# 1        1       SG  INO
# 2        2       SF  CHS
# 3        3        F  TOT
# 4        1        F  DNN

# %%
field_goals = stats.groupby('Player').sum()['FG']
field_goals = pd.DataFrame(field_goals)
field_goals.reset_index(inplace=True)
field_goals.columns = field_goals.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(field_goals, totals, how='left', on='player')
totals.rename(columns = {'fg': 'field_goals'}, inplace=True)
totals.head()
# Out:
#           player  field_goals  shooting_percent  player_efficiency_rating  \
# 0     A.C. Green       4778.0          0.543556                 13.872222
# 1  A.J. Bramlett          4.0          0.190000                 -0.400000
# 2   A.J. English        617.0          0.480000                 11.550000
# 3    A.J. Guyton        166.0          0.324000                  4.366667
# 4   A.J. Hammons         17.0          0.472000                  8.400000
#
#    games_played  seasons position team
# 0        1361.0       18      G-F  FTW
# 1           8.0        1       SG  INO
# 2         151.0        2       SF  CHS
# 3          80.0        3        F  TOT
# 4          22.0        1        F  DNN

# %%
fg_percent = stats.groupby('Player').mean()['FG%']
fg_percent = pd.DataFrame(fg_percent)
fg_percent.reset_index(inplace=True)
fg_percent.columns = fg_percent.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(fg_percent, totals, how='left', on='player')
totals.rename(columns = {'fg%': 'fg_percent'}, inplace=True)
totals.head()
# Out:
#           player  fg_percent  field_goals  shooting_percent  \
# 0     A.C. Green    0.487667       4778.0          0.543556
# 1  A.J. Bramlett    0.190000          4.0          0.190000
# 2   A.J. English    0.436000        617.0          0.480000
# 3    A.J. Guyton    0.255667        166.0          0.324000
# 4   A.J. Hammons    0.405000         17.0          0.472000
#
#    player_efficiency_rating  games_played  seasons position team
# 0                 13.872222        1361.0       18      G-F  FTW
# 1                 -0.400000           8.0        1       SG  INO
# 2                 11.550000         151.0        2       SF  CHS
# 3                  4.366667          80.0        3        F  TOT
# 4                  8.400000          22.0        1        F  DNN

# %%
three_p_made = stats.groupby('Player').sum()['3P']
three_p_made = pd.DataFrame(three_p_made)
three_p_made.reset_index(inplace=True)
three_p_made.columns = three_p_made.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(three_p_made, totals, how='left', on='player')
totals.rename(columns = {'3p': '3p_made'}, inplace=True)
totals.head()
# Out:
#           player  3p_made  fg_percent  field_goals  shooting_percent  \
# 0     A.C. Green    125.0    0.487667       4778.0          0.543556
# 1  A.J. Bramlett      0.0    0.190000          4.0          0.190000
# 2   A.J. English      9.0    0.436000        617.0          0.480000
# 3    A.J. Guyton     73.0    0.255667        166.0          0.324000
# 4   A.J. Hammons      5.0    0.405000         17.0          0.472000
#
#    player_efficiency_rating  games_played  seasons position team
# 0                 13.872222        1361.0       18      G-F  FTW
# 1                 -0.400000           8.0        1       SG  INO
# 2                 11.550000         151.0        2       SF  CHS
# 3                  4.366667          80.0        3        F  TOT
# 4                  8.400000          22.0        1        F  DNN

# %%
three_p_per = stats.groupby('Player').mean()['3P%']
three_p_per = pd.DataFrame(three_p_per)
three_p_per.reset_index(inplace=True)
three_p_per.columns = three_p_per.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(three_p_per, totals, how='left', on='player')
totals.rename(columns = {'3p%': '3p_percentage'}, inplace=True)
totals.head()
# Out:
#           player  3p_percentage  3p_made  fg_percent  field_goals  \
# 0     A.C. Green       0.146833    125.0    0.487667       4778.0
# 1  A.J. Bramlett            NaN      0.0    0.190000          4.0
# 2   A.J. English       0.136500      9.0    0.436000        617.0
# 3    A.J. Guyton       0.255000     73.0    0.255667        166.0
# 4   A.J. Hammons       0.500000      5.0    0.405000         17.0
#
#    shooting_percent  player_efficiency_rating  games_played  seasons position  \
# 0          0.543556                 13.872222        1361.0       18      G-F
# 1          0.190000                 -0.400000           8.0        1       SG
# 2          0.480000                 11.550000         151.0        2       SF
# 3          0.324000                  4.366667          80.0        3        F
# 4          0.472000                  8.400000          22.0        1        F
#
#   team
# 0  FTW
# 1  INO
# 2  CHS
# 3  TOT
# 4  DNN

# %%
two_p_made = stats.groupby('Player').sum()['2P']
two_p_made = pd.DataFrame(two_p_made)
two_p_made.reset_index(inplace=True)
two_p_made.columns = two_p_made.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(two_p_made, totals, how='left', on='player')
totals.rename(columns = {'2p': '2p_made'}, inplace=True)
totals.head()
# Out:
#           player  2p_made  3p_percentage  3p_made  fg_percent  field_goals  \
# 0     A.C. Green   4653.0       0.146833    125.0    0.487667       4778.0
# 1  A.J. Bramlett      4.0            NaN      0.0    0.190000          4.0
# 2   A.J. English    608.0       0.136500      9.0    0.436000        617.0
# 3    A.J. Guyton     93.0       0.255000     73.0    0.255667        166.0
# 4   A.J. Hammons     12.0       0.500000      5.0    0.405000         17.0
#
#    shooting_percent  player_efficiency_rating  games_played  seasons position  \
# 0          0.543556                 13.872222        1361.0       18      G-F
# 1          0.190000                 -0.400000           8.0        1       SG
# 2          0.480000                 11.550000         151.0        2       SF
# 3          0.324000                  4.366667          80.0        3        F
# 4          0.472000                  8.400000          22.0        1        F
#
#   team
# 0  FTW
# 1  INO
# 2  CHS
# 3  TOT
# 4  DNN

# %%
two_p_per = stats.groupby('Player').mean()['2P%']
two_p_per = pd.DataFrame(two_p_per)
two_p_per.reset_index(inplace=True)
two_p_per.columns = two_p_per.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(two_p_per, totals, how='left', on='player')
totals.rename(columns = {'2p%': '2p_percentage'}, inplace=True)
totals.head()
# Out:
#           player  2p_percentage  2p_made  3p_percentage  3p_made  fg_percent  \
# 0     A.C. Green       0.501889   4653.0       0.146833    125.0    0.487667
# 1  A.J. Bramlett       0.190000      4.0            NaN      0.0    0.190000
# 2   A.J. English       0.450500    608.0       0.136500      9.0    0.436000
# 3    A.J. Guyton       0.254000     93.0       0.255000     73.0    0.255667
# 4   A.J. Hammons       0.375000     12.0       0.500000      5.0    0.405000
#
#    field_goals  shooting_percent  player_efficiency_rating  games_played  \
# 0       4778.0          0.543556                 13.872222        1361.0
# 1          4.0          0.190000                 -0.400000           8.0
# 2        617.0          0.480000                 11.550000         151.0
# 3        166.0          0.324000                  4.366667          80.0
# 4         17.0          0.472000                  8.400000          22.0
#
#    seasons position team
# 0       18      G-F  FTW
# 1        1       SG  INO
# 2        2       SF  CHS
# 3        3        F  TOT
# 4        1        F  DNN

# %%
free_throws_made = stats.groupby('Player').sum()['FT']
free_throws_made = pd.DataFrame(free_throws_made)
free_throws_made.reset_index(inplace=True)
free_throws_made.columns = free_throws_made.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(free_throws_made, totals, how='left', on='player')
totals.rename(columns = {'ft': 'free_throws_made'}, inplace=True)
totals.head()
# Out:
#           player  free_throws_made  2p_percentage  2p_made  3p_percentage  \
# 0     A.C. Green            3247.0       0.501889   4653.0       0.146833
# 1  A.J. Bramlett               0.0       0.190000      4.0            NaN
# 2   A.J. English             259.0       0.450500    608.0       0.136500
# 3    A.J. Guyton              37.0       0.254000     93.0       0.255000
# 4   A.J. Hammons               9.0       0.375000     12.0       0.500000
#
#    3p_made  fg_percent  field_goals  shooting_percent  \
# 0    125.0    0.487667       4778.0          0.543556
# 1      0.0    0.190000          4.0          0.190000
# 2      9.0    0.436000        617.0          0.480000
# 3     73.0    0.255667        166.0          0.324000
# 4      5.0    0.405000         17.0          0.472000
#
#    player_efficiency_rating  games_played  seasons position team
# 0                 13.872222        1361.0       18      G-F  FTW
# 1                 -0.400000           8.0        1       SG  INO
# 2                 11.550000         151.0        2       SF  CHS
# 3                  4.366667          80.0        3        F  TOT
# 4                  8.400000          22.0        1        F  DNN

# %%
free_throw_per = stats.groupby('Player').mean()['FT%']
free_throw_per = pd.DataFrame(free_throw_per)
free_throw_per.reset_index(inplace=True)
free_throw_per.columns = free_throw_per.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(free_throw_per, totals, how='left', on='player')
totals.rename(columns = {'ft%': 'ft_percentage'}, inplace=True)
totals.head()
# Out:
#           player  ft_percentage  free_throws_made  2p_percentage  2p_made  \
# 0     A.C. Green       0.708056            3247.0       0.501889   4653.0
# 1  A.J. Bramlett            NaN               0.0       0.190000      4.0
# 2   A.J. English       0.774000             259.0       0.450500    608.0
# 3    A.J. Guyton       0.824000              37.0       0.254000     93.0
# 4   A.J. Hammons       0.450000               9.0       0.375000     12.0
#
#    3p_percentage  3p_made  fg_percent  field_goals  shooting_percent  \
# 0       0.146833    125.0    0.487667       4778.0          0.543556
# 1            NaN      0.0    0.190000          4.0          0.190000
# 2       0.136500      9.0    0.436000        617.0          0.480000
# 3       0.255000     73.0    0.255667        166.0          0.324000
# 4       0.500000      5.0    0.405000         17.0          0.472000
#
#    player_efficiency_rating  games_played  seasons position team
# 0                 13.872222        1361.0       18      G-F  FTW
# 1                 -0.400000           8.0        1       SG  INO
# 2                 11.550000         151.0        2       SF  CHS
# 3                  4.366667          80.0        3        F  TOT
# 4                  8.400000          22.0        1        F  DNN

# %%
offensive_rebounds = stats.groupby('Player').sum()['ORB']
offensive_rebounds = pd.DataFrame(offensive_rebounds)
offensive_rebounds.reset_index(inplace=True)
offensive_rebounds.columns = offensive_rebounds.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(offensive_rebounds, totals, how='left', on='player')
totals.rename(columns = {'orb': 'offensive_rebounds'}, inplace=True)
totals.head()
# Out:
#           player  offensive_rebounds  ft_percentage  free_throws_made  \
# 0     A.C. Green              3576.0       0.708056            3247.0
# 1  A.J. Bramlett                12.0            NaN               0.0
# 2   A.J. English               140.0       0.774000             259.0
# 3    A.J. Guyton                22.0       0.824000              37.0
# 4   A.J. Hammons                 8.0       0.450000               9.0
#
#    2p_percentage  2p_made  3p_percentage  3p_made  fg_percent  field_goals  \
# 0       0.501889   4653.0       0.146833    125.0    0.487667       4778.0
# 1       0.190000      4.0            NaN      0.0    0.190000          4.0
# 2       0.450500    608.0       0.136500      9.0    0.436000        617.0
# 3       0.254000     93.0       0.255000     73.0    0.255667        166.0
# 4       0.375000     12.0       0.500000      5.0    0.405000         17.0
#
#    shooting_percent  player_efficiency_rating  games_played  seasons position  \
# 0          0.543556                 13.872222        1361.0       18      G-F
# 1          0.190000                 -0.400000           8.0        1       SG
# 2          0.480000                 11.550000         151.0        2       SF
# 3          0.324000                  4.366667          80.0        3        F
# 4          0.472000                  8.400000          22.0        1        F
#
#   team
# 0  FTW
# 1  INO
# 2  CHS
# 3  TOT
# 4  DNN

# %%
defensive_rebounds = stats.groupby('Player').sum()['DRB']
defensive_rebounds = pd.DataFrame(defensive_rebounds)
defensive_rebounds.reset_index(inplace=True)
defensive_rebounds.columns = defensive_rebounds.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(defensive_rebounds, totals, how='left', on='player')
totals.rename(columns = {'drb': 'defensive_rebounds'}, inplace=True)
totals.head()
# Out:
#           player  defensive_rebounds  offensive_rebounds  ft_percentage  \
# 0     A.C. Green              6553.0              3576.0       0.708056
# 1  A.J. Bramlett                10.0                12.0            NaN
# 2   A.J. English               175.0               140.0       0.774000
# 3    A.J. Guyton                58.0                22.0       0.824000
# 4   A.J. Hammons                28.0                 8.0       0.450000
#
#    free_throws_made  2p_percentage  2p_made  3p_percentage  3p_made  \
# 0            3247.0       0.501889   4653.0       0.146833    125.0
# 1               0.0       0.190000      4.0            NaN      0.0
# 2             259.0       0.450500    608.0       0.136500      9.0
# 3              37.0       0.254000     93.0       0.255000     73.0
# 4               9.0       0.375000     12.0       0.500000      5.0
#
#    fg_percent  field_goals  shooting_percent  player_efficiency_rating  \
# 0    0.487667       4778.0          0.543556                 13.872222
# 1    0.190000          4.0          0.190000                 -0.400000
# 2    0.436000        617.0          0.480000                 11.550000
# 3    0.255667        166.0          0.324000                  4.366667
# 4    0.405000         17.0          0.472000                  8.400000
#
#    games_played  seasons position team
# 0        1361.0       18      G-F  FTW
# 1           8.0        1       SG  INO
# 2         151.0        2       SF  CHS
# 3          80.0        3        F  TOT
# 4          22.0        1        F  DNN

# %%
total_rebounds = stats.groupby('Player').sum()['TRB']
total_rebounds = pd.DataFrame(total_rebounds)
total_rebounds.reset_index(inplace=True)
total_rebounds.columns = total_rebounds.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(total_rebounds, totals, how='left', on='player')
totals.rename(columns = {'trb': 'total_rebounds'}, inplace=True)
totals.head()
# Out:
#           player  total_rebounds  defensive_rebounds  offensive_rebounds  \
# 0     A.C. Green         10129.0              6553.0              3576.0
# 1  A.J. Bramlett            22.0                10.0                12.0
# 2   A.J. English           315.0               175.0               140.0
# 3    A.J. Guyton            80.0                58.0                22.0
# 4   A.J. Hammons            36.0                28.0                 8.0
#
#    ft_percentage  free_throws_made  2p_percentage  2p_made  3p_percentage  \
# 0       0.708056            3247.0       0.501889   4653.0       0.146833
# 1            NaN               0.0       0.190000      4.0            NaN
# 2       0.774000             259.0       0.450500    608.0       0.136500
# 3       0.824000              37.0       0.254000     93.0       0.255000
# 4       0.450000               9.0       0.375000     12.0       0.500000
#
#    3p_made  fg_percent  field_goals  shooting_percent  \
# 0    125.0    0.487667       4778.0          0.543556
# 1      0.0    0.190000          4.0          0.190000
# 2      9.0    0.436000        617.0          0.480000
# 3     73.0    0.255667        166.0          0.324000
# 4      5.0    0.405000         17.0          0.472000
#
#    player_efficiency_rating  games_played  seasons position team
# 0                 13.872222        1361.0       18      G-F  FTW
# 1                 -0.400000           8.0        1       SG  INO
# 2                 11.550000         151.0        2       SF  CHS
# 3                  4.366667          80.0        3        F  TOT
# 4                  8.400000          22.0        1        F  DNN

# %%
total_assists = stats.groupby('Player').sum()['AST']
total_assists = pd.DataFrame(total_assists)
total_assists.reset_index(inplace=True)
total_assists.columns = total_assists.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(total_assists, totals, how='left', on='player')
totals.rename(columns = {'ast': 'total_assists'}, inplace=True)
totals.head()
# Out:
#           player  total_assists  total_rebounds  defensive_rebounds  \
# 0     A.C. Green         1469.0         10129.0              6553.0
# 1  A.J. Bramlett            0.0            22.0                10.0
# 2   A.J. English          320.0           315.0               175.0
# 3    A.J. Guyton          147.0            80.0                58.0
# 4   A.J. Hammons            4.0            36.0                28.0
#
#    offensive_rebounds  ft_percentage  free_throws_made  2p_percentage  \
# 0              3576.0       0.708056            3247.0       0.501889
# 1                12.0            NaN               0.0       0.190000
# 2               140.0       0.774000             259.0       0.450500
# 3                22.0       0.824000              37.0       0.254000
# 4                 8.0       0.450000               9.0       0.375000
#
#    2p_made  3p_percentage  3p_made  fg_percent  field_goals  shooting_percent  \
# 0   4653.0       0.146833    125.0    0.487667       4778.0          0.543556
# 1      4.0            NaN      0.0    0.190000          4.0          0.190000
# 2    608.0       0.136500      9.0    0.436000        617.0          0.480000
# 3     93.0       0.255000     73.0    0.255667        166.0          0.324000
# 4     12.0       0.500000      5.0    0.405000         17.0          0.472000
#
#    player_efficiency_rating  games_played  seasons position team
# 0                 13.872222        1361.0       18      G-F  FTW
# 1                 -0.400000           8.0        1       SG  INO
# 2                 11.550000         151.0        2       SF  CHS
# 3                  4.366667          80.0        3        F  TOT
# 4                  8.400000          22.0        1        F  DNN

# %%
total_steals = stats.groupby('Player').sum()['STL']
total_steals = pd.DataFrame(total_steals)
total_steals.reset_index(inplace=True)
total_steals.columns = total_steals.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(total_steals, totals, how='left', on='player')
totals.rename(columns = {'stl': 'total_steals'}, inplace=True)
totals.head()
# Out:
#           player  total_steals  total_assists  total_rebounds  \
# 0     A.C. Green        1103.0         1469.0         10129.0
# 1  A.J. Bramlett           1.0            0.0            22.0
# 2   A.J. English          57.0          320.0           315.0
# 3    A.J. Guyton          20.0          147.0            80.0
# 4   A.J. Hammons           1.0            4.0            36.0
#
#    defensive_rebounds  offensive_rebounds  ft_percentage  free_throws_made  \
# 0              6553.0              3576.0       0.708056            3247.0
# 1                10.0                12.0            NaN               0.0
# 2               175.0               140.0       0.774000             259.0
# 3                58.0                22.0       0.824000              37.0
# 4                28.0                 8.0       0.450000               9.0
#
#    2p_percentage  2p_made  3p_percentage  3p_made  fg_percent  field_goals  \
# 0       0.501889   4653.0       0.146833    125.0    0.487667       4778.0
# 1       0.190000      4.0            NaN      0.0    0.190000          4.0
# 2       0.450500    608.0       0.136500      9.0    0.436000        617.0
# 3       0.254000     93.0       0.255000     73.0    0.255667        166.0
# 4       0.375000     12.0       0.500000      5.0    0.405000         17.0
#
#    shooting_percent  player_efficiency_rating  games_played  seasons position  \
# 0          0.543556                 13.872222        1361.0       18      G-F
# 1          0.190000                 -0.400000           8.0        1       SG
# 2          0.480000                 11.550000         151.0        2       SF
# 3          0.324000                  4.366667          80.0        3        F
# 4          0.472000                  8.400000          22.0        1        F
#
#   team
# 0  FTW
# 1  INO
# 2  CHS
# 3  TOT
# 4  DNN

# %%
total_blocks = stats.groupby('Player').sum()['BLK']
total_blocks = pd.DataFrame(total_blocks)
total_blocks.reset_index(inplace=True)
total_blocks.columns = total_blocks.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(total_blocks, totals, how='left', on='player')
totals.rename(columns = {'blk': 'total_blocks'}, inplace=True)
totals.head()
# Out:
#           player  total_blocks  total_steals  total_assists  total_rebounds  \
# 0     A.C. Green         562.0        1103.0         1469.0         10129.0
# 1  A.J. Bramlett           0.0           1.0            0.0            22.0
# 2   A.J. English          24.0          57.0          320.0           315.0
# 3    A.J. Guyton          12.0          20.0          147.0            80.0
# 4   A.J. Hammons          13.0           1.0            4.0            36.0
#
#    defensive_rebounds  offensive_rebounds  ft_percentage  free_throws_made  \
# 0              6553.0              3576.0       0.708056            3247.0
# 1                10.0                12.0            NaN               0.0
# 2               175.0               140.0       0.774000             259.0
# 3                58.0                22.0       0.824000              37.0
# 4                28.0                 8.0       0.450000               9.0
#
#    2p_percentage  ...  3p_percentage  3p_made  fg_percent  field_goals  \
# 0       0.501889  ...       0.146833    125.0    0.487667       4778.0
# 1       0.190000  ...            NaN      0.0    0.190000          4.0
# 2       0.450500  ...       0.136500      9.0    0.436000        617.0
# 3       0.254000  ...       0.255000     73.0    0.255667        166.0
# 4       0.375000  ...       0.500000      5.0    0.405000         17.0
#
#    shooting_percent  player_efficiency_rating  games_played  seasons  \
# 0          0.543556                 13.872222        1361.0       18
# 1          0.190000                 -0.400000           8.0        1
# 2          0.480000                 11.550000         151.0        2
# 3          0.324000                  4.366667          80.0        3
# 4          0.472000                  8.400000          22.0        1
#
#    position team
# 0       G-F  FTW
# 1        SG  INO
# 2        SF  CHS
# 3         F  TOT
# 4         F  DNN
#
# [5 rows x 21 columns]

# %%
total_turnovers = stats.groupby('Player').sum()['TOV']
total_turnovers = pd.DataFrame(total_turnovers)
total_turnovers.reset_index(inplace=True)
total_turnovers.columns = total_turnovers.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(total_turnovers, totals, how='left', on='player')
totals.rename(columns = {'tov': 'total_turnovers'}, inplace=True)
totals.head()
# Out:
#           player  total_turnovers  total_blocks  total_steals  total_assists  \
# 0     A.C. Green           1508.0         562.0        1103.0         1469.0
# 1  A.J. Bramlett              3.0           0.0           1.0            0.0
# 2   A.J. English            203.0          24.0          57.0          320.0
# 3    A.J. Guyton             62.0          12.0          20.0          147.0
# 4   A.J. Hammons             10.0          13.0           1.0            4.0
#
#    total_rebounds  defensive_rebounds  offensive_rebounds  ft_percentage  \
# 0         10129.0              6553.0              3576.0       0.708056
# 1            22.0                10.0                12.0            NaN
# 2           315.0               175.0               140.0       0.774000
# 3            80.0                58.0                22.0       0.824000
# 4            36.0                28.0                 8.0       0.450000
#
#    free_throws_made  ...  3p_percentage  3p_made  fg_percent  field_goals  \
# 0            3247.0  ...       0.146833    125.0    0.487667       4778.0
# 1               0.0  ...            NaN      0.0    0.190000          4.0
# 2             259.0  ...       0.136500      9.0    0.436000        617.0
# 3              37.0  ...       0.255000     73.0    0.255667        166.0
# 4               9.0  ...       0.500000      5.0    0.405000         17.0
#
#    shooting_percent  player_efficiency_rating  games_played  seasons  \
# 0          0.543556                 13.872222        1361.0       18
# 1          0.190000                 -0.400000           8.0        1
# 2          0.480000                 11.550000         151.0        2
# 3          0.324000                  4.366667          80.0        3
# 4          0.472000                  8.400000          22.0        1
#
#    position  team
# 0       G-F   FTW
# 1        SG   INO
# 2        SF   CHS
# 3         F   TOT
# 4         F   DNN
#
# [5 rows x 22 columns]

# %%
total_personal_fouls = stats.groupby('Player').sum()['PF']
total_personal_fouls = pd.DataFrame(total_personal_fouls)
total_personal_fouls.reset_index(inplace=True)
total_personal_fouls.columns = total_personal_fouls.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(total_personal_fouls, totals, how='left', on='player')
totals.rename(columns = {'pf': 'total_personal_fouls'}, inplace=True)
totals.head()
# Out:
#           player  total_personal_fouls  total_turnovers  total_blocks  \
# 0     A.C. Green                2581.0           1508.0         562.0
# 1  A.J. Bramlett                  13.0              3.0           0.0
# 2   A.J. English                 287.0            203.0          24.0
# 3    A.J. Guyton                  58.0             62.0          12.0
# 4   A.J. Hammons                  21.0             10.0          13.0
#
#    total_steals  total_assists  total_rebounds  defensive_rebounds  \
# 0        1103.0         1469.0         10129.0              6553.0
# 1           1.0            0.0            22.0                10.0
# 2          57.0          320.0           315.0               175.0
# 3          20.0          147.0            80.0                58.0
# 4           1.0            4.0            36.0                28.0
#
#    offensive_rebounds  ft_percentage  ...  3p_percentage  3p_made  fg_percent  \
# 0              3576.0       0.708056  ...       0.146833    125.0    0.487667
# 1                12.0            NaN  ...            NaN      0.0    0.190000
# 2               140.0       0.774000  ...       0.136500      9.0    0.436000
# 3                22.0       0.824000  ...       0.255000     73.0    0.255667
# 4                 8.0       0.450000  ...       0.500000      5.0    0.405000
#
#    field_goals  shooting_percent  player_efficiency_rating  games_played  \
# 0       4778.0          0.543556                 13.872222        1361.0
# 1          4.0          0.190000                 -0.400000           8.0
# 2        617.0          0.480000                 11.550000         151.0
# 3        166.0          0.324000                  4.366667          80.0
# 4         17.0          0.472000                  8.400000          22.0
#
#    seasons  position  team
# 0       18       G-F   FTW
# 1        1        SG   INO
# 2        2        SF   CHS
# 3        3         F   TOT
# 4        1         F   DNN
#
# [5 rows x 23 columns]

# %%
total_points = stats.groupby('Player').sum()['PTS']
total_points = pd.DataFrame(total_points)
total_points.reset_index(inplace=True)
total_points.columns = total_points.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(total_points, totals, how='left', on='player')
totals.rename(columns = {'pts': 'total_points'}, inplace=True)
totals.head()
# Out:
#           player  total_points  total_personal_fouls  total_turnovers  \
# 0     A.C. Green       12928.0                2581.0           1508.0
# 1  A.J. Bramlett           8.0                  13.0              3.0
# 2   A.J. English        1502.0                 287.0            203.0
# 3    A.J. Guyton         442.0                  58.0             62.0
# 4   A.J. Hammons          48.0                  21.0             10.0
#
#    total_blocks  total_steals  total_assists  total_rebounds  \
# 0         562.0        1103.0         1469.0         10129.0
# 1           0.0           1.0            0.0            22.0
# 2          24.0          57.0          320.0           315.0
# 3          12.0          20.0          147.0            80.0
# 4          13.0           1.0            4.0            36.0
#
#    defensive_rebounds  offensive_rebounds  ...  3p_percentage  3p_made  \
# 0              6553.0              3576.0  ...       0.146833    125.0
# 1                10.0                12.0  ...            NaN      0.0
# 2               175.0               140.0  ...       0.136500      9.0
# 3                58.0                22.0  ...       0.255000     73.0
# 4                28.0                 8.0  ...       0.500000      5.0
#
#    fg_percent  field_goals  shooting_percent  player_efficiency_rating  \
# 0    0.487667       4778.0          0.543556                 13.872222
# 1    0.190000          4.0          0.190000                 -0.400000
# 2    0.436000        617.0          0.480000                 11.550000
# 3    0.255667        166.0          0.324000                  4.366667
# 4    0.405000         17.0          0.472000                  8.400000
#
#    games_played  seasons  position  team
# 0        1361.0       18       G-F   FTW
# 1           8.0        1        SG   INO
# 2         151.0        2        SF   CHS
# 3          80.0        3         F   TOT
# 4          22.0        1         F   DNN
#
# [5 rows x 24 columns]

# %%
hall_of_fame = totals[totals.games_played >= 164]

# %%
list_of_hall_of_famers = []
for i, row in hall_of_fame.iterrows():
    if '*' in row['player']:
        list_of_hall_of_famers.append(row['player'])
list_of_hall_of_famers = list(set(list_of_hall_of_famers))

# %%
def is_hall_of_famer(x):
    if '*' in x:
        return 1
    else:
        return 0

# %%
hall_of_fame['HOF'] = hall_of_fame['player'].apply(is_hall_of_famer)
# Out:
# <ipython-input-43-3cbc13a66797>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hall_of_fame['HOF'] = hall_of_fame['player'].apply(is_hall_of_famer)

# %%
hall_of_fame = hall_of_fame.set_index('player')

# %%
hall_of_fame.corr()['HOF'].map(abs).sort_values(ascending=False)
# Out:
# HOF                         1.000000
# free_throws_made            0.469877
# 2p_made                     0.443314
# total_points                0.413747
# field_goals                 0.409497
# total_rebounds              0.379603
# player_efficiency_rating    0.376964
# total_personal_fouls        0.307770
# total_assists               0.280950
# games_played                0.215158
# total_blocks                0.131520
# defensive_rebounds          0.111382
# offensive_rebounds          0.108104
# seasons                     0.102158
# total_turnovers             0.092802
# total_steals                0.085595
# ft_percentage               0.078167
# fg_percent                  0.076635
# shooting_percent            0.072490
# 3p_made                     0.055085
# 2p_percentage               0.025016
# 3p_percentage               0.019597
# Name: HOF, dtype: float64

# %%
total_mvp = stats.groupby('Player').sum()['MVP']
total_mvp = pd.DataFrame(total_mvp)
total_mvp.reset_index(inplace=True)
total_mvp.columns = total_mvp.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(total_mvp, totals, how='left', on='player')
totals.rename(columns = {'MVP': 'total_MVP'}, inplace=True)
totals.head()
# Out:
#           player  mvp  total_points  total_personal_fouls  total_turnovers  \
# 0     A.C. Green    0       12928.0                2581.0           1508.0
# 1  A.J. Bramlett    0           8.0                  13.0              3.0
# 2   A.J. English    0        1502.0                 287.0            203.0
# 3    A.J. Guyton    0         442.0                  58.0             62.0
# 4   A.J. Hammons    0          48.0                  21.0             10.0
#
#    total_blocks  total_steals  total_assists  total_rebounds  \
# 0         562.0        1103.0         1469.0         10129.0
# 1           0.0           1.0            0.0            22.0
# 2          24.0          57.0          320.0           315.0
# 3          12.0          20.0          147.0            80.0
# 4          13.0           1.0            4.0            36.0
#
#    defensive_rebounds  ...  3p_percentage  3p_made  fg_percent  field_goals  \
# 0              6553.0  ...       0.146833    125.0    0.487667       4778.0
# 1                10.0  ...            NaN      0.0    0.190000          4.0
# 2               175.0  ...       0.136500      9.0    0.436000        617.0
# 3                58.0  ...       0.255000     73.0    0.255667        166.0
# 4                28.0  ...       0.500000      5.0    0.405000         17.0
#
#    shooting_percent  player_efficiency_rating  games_played  seasons  \
# 0          0.543556                 13.872222        1361.0       18
# 1          0.190000                 -0.400000           8.0        1
# 2          0.480000                 11.550000         151.0        2
# 3          0.324000                  4.366667          80.0        3
# 4          0.472000                  8.400000          22.0        1
#
#    position  team
# 0       G-F   FTW
# 1        SG   INO
# 2        SF   CHS
# 3         F   TOT
# 4         F   DNN
#
# [5 rows x 25 columns]

# %%
total_rings = stats.groupby('Player').sum()['rings']
total_rings = pd.DataFrame(total_rings)
total_rings.reset_index(inplace=True)
total_rings.columns = total_rings.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(total_rings, totals, how='left', on='player')
totals.rename(columns = {'rings': 'total_rings'}, inplace=True)
totals.head()
# Out:
#           player  total_rings  mvp  total_points  total_personal_fouls  \
# 0     A.C. Green            3    0       12928.0                2581.0
# 1  A.J. Bramlett            0    0           8.0                  13.0
# 2   A.J. English            0    0        1502.0                 287.0
# 3    A.J. Guyton            0    0         442.0                  58.0
# 4   A.J. Hammons            0    0          48.0                  21.0
#
#    total_turnovers  total_blocks  total_steals  total_assists  total_rebounds  \
# 0           1508.0         562.0        1103.0         1469.0         10129.0
# 1              3.0           0.0           1.0            0.0            22.0
# 2            203.0          24.0          57.0          320.0           315.0
# 3             62.0          12.0          20.0          147.0            80.0
# 4             10.0          13.0           1.0            4.0            36.0
#
#    ...  3p_percentage  3p_made  fg_percent  field_goals  shooting_percent  \
# 0  ...       0.146833    125.0    0.487667       4778.0          0.543556
# 1  ...            NaN      0.0    0.190000          4.0          0.190000
# 2  ...       0.136500      9.0    0.436000        617.0          0.480000
# 3  ...       0.255000     73.0    0.255667        166.0          0.324000
# 4  ...       0.500000      5.0    0.405000         17.0          0.472000
#
#    player_efficiency_rating  games_played  seasons  position  team
# 0                 13.872222        1361.0       18       G-F   FTW
# 1                 -0.400000           8.0        1        SG   INO
# 2                 11.550000         151.0        2        SF   CHS
# 3                  4.366667          80.0        3         F   TOT
# 4                  8.400000          22.0        1         F   DNN
#
# [5 rows x 26 columns]

# %%
finals_mvps = stats.groupby('Player').sum()['finals_mvp']
finals_mvps = pd.DataFrame(finals_mvps)
finals_mvps.reset_index(inplace=True)
finals_mvps.columns = finals_mvps.columns.str.replace(" ", "_").str.lower()
totals = pd.merge(finals_mvps, totals, how='left', on='player')
totals.rename(columns = {'finals_mvp': 'finals_mvps'}, inplace=True)
totals.head()
# Out:
#           player  finals_mvps  total_rings  mvp  total_points  \
# 0     A.C. Green            0            3    0       12928.0
# 1  A.J. Bramlett            0            0    0           8.0
# 2   A.J. English            0            0    0        1502.0
# 3    A.J. Guyton            0            0    0         442.0
# 4   A.J. Hammons            0            0    0          48.0
#
#    total_personal_fouls  total_turnovers  total_blocks  total_steals  \
# 0                2581.0           1508.0         562.0        1103.0
# 1                  13.0              3.0           0.0           1.0
# 2                 287.0            203.0          24.0          57.0
# 3                  58.0             62.0          12.0          20.0
# 4                  21.0             10.0          13.0           1.0
#
#    total_assists  ...  3p_percentage  3p_made  fg_percent  field_goals  \
# 0         1469.0  ...       0.146833    125.0    0.487667       4778.0
# 1            0.0  ...            NaN      0.0    0.190000          4.0
# 2          320.0  ...       0.136500      9.0    0.436000        617.0
# 3          147.0  ...       0.255000     73.0    0.255667        166.0
# 4            4.0  ...       0.500000      5.0    0.405000         17.0
#
#    shooting_percent  player_efficiency_rating  games_played  seasons  \
# 0          0.543556                 13.872222        1361.0       18
# 1          0.190000                 -0.400000           8.0        1
# 2          0.480000                 11.550000         151.0        2
# 3          0.324000                  4.366667          80.0        3
# 4          0.472000                  8.400000          22.0        1
#
#    position  team
# 0       G-F   FTW
# 1        SG   INO
# 2        SF   CHS
# 3         F   TOT
# 4         F   DNN
#
# [5 rows x 27 columns]

# %%
totals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3921 entries, 0 to 3920
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   player                    3921 non-null   object
#  1   finals_mvps               3921 non-null   int64
#  2   total_rings               3921 non-null   int64
#  3   mvp                       3921 non-null   int64
#  4   total_points              3921 non-null   float64
#  5   total_personal_fouls      3921 non-null   float64
#  6   total_turnovers           3921 non-null   float64
#  7   total_blocks              3921 non-null   float64
#  8   total_steals              3921 non-null   float64
#  9   total_assists             3921 non-null   float64
#  10  total_rebounds            3921 non-null   float64
#  11  defensive_rebounds        3921 non-null   float64
#  12  offensive_rebounds        3921 non-null   float64
#  13  ft_percentage             3771 non-null   float64
#  14  free_throws_made          3921 non-null   float64
#  15  2p_percentage             3903 non-null   float64
#  16  2p_made                   3921 non-null   float64
#  17  3p_percentage             2457 non-null   float64
#  18  3p_made                   3921 non-null   float64
#  19  fg_percent                3907 non-null   float64
#  20  field_goals               3921 non-null   float64
#  21  shooting_percent          3908 non-null   float64
#  22  player_efficiency_rating  3763 non-null   float64
#  23  games_played              3921 non-null   float64
#  24  seasons                   3921 non-null   int64
#  25  position                  3897 non-null   object
#  26  team                      3897 non-null   object
# dtypes: float64(20), int64(4), object(3)
# memory usage: 857.7+ KB

# %%
totals.tail(20)
# Out:
#                   player  finals_mvps  total_rings  mvp  total_points  \
# 3901        Yogi Ferrell            0            0    0         924.0
# 3902         York Larese            0            0    0         604.0
# 3903         Yuta Tabuse            0            0    0           7.0
# 3904         Yvon Joseph            0            0    0           2.0
# 3905      Zabian Dowdell            0            0    0         121.0
# 3906         Zach LaVine            0            0    0        2817.0
# 3907       Zach Randolph            0            0    0       18762.0
# 3908     Zaid Abdul-Aziz            0            0    0        4978.0
# 3909           Zan Tabak            0            1    0        1540.0
# 3910     Zarko Cabarkapa            0            0    0         878.0
# 3911       Zarko Paspalj            0            0    0          72.0
# 3912       Zaza Pachulia            0            1    0        6774.0
# 3913       Zeke Sinicola            0            0    0          13.0
# 3914        Zeke Zawoluk            0            0    0        1210.0
# 3915      Zeljko Rebraca            0            1    0        1367.0
# 3916        Zelmo Beaty*            0            0    0        9107.0
# 3917     Zendon Hamilton            0            0    0         611.0
# 3918        Zoran Dragic            0            0    0          56.0
# 3919      Zoran Planinic            0            0    0         561.0
# 3920  Zydrunas Ilgauskas            0            0    0       10976.0
#
#       total_personal_fouls  total_turnovers  total_blocks  total_steals  \
# 3901                 180.0            140.0          18.0          84.0
# 3902                 208.0              0.0           0.0           0.0
# 3903                   1.0              1.0           0.0           0.0
# 3904                   1.0              0.0           0.0           0.0
# 3905                  30.0             29.0           2.0          20.0
# 3906                 455.0            433.0          37.0         164.0
# 3907                2643.0           2288.0         307.0         835.0
# 3908                1264.0             28.0         208.0         134.0
# 3909                 740.0            330.0         164.0          85.0
# 3910                 280.0            149.0          30.0          43.0
# 3911                  37.0             21.0           7.0           3.0
# 3912                2465.0           1316.0         344.0         699.0
# 3913                  10.0              0.0           0.0           0.0
# 3914                 450.0              0.0           0.0           0.0
# 3915                 564.0            220.0         171.0          62.0
# 3916                2132.0              0.0          29.0          45.0
# 3917                 220.0            114.0          28.0          43.0
# 3918                  12.0             10.0           0.0           4.0
# 3919                 237.0            120.0           7.0          58.0
# 3920                2776.0           1509.0        1327.0         421.0
#
#       total_assists  ...  3p_percentage  3p_made  fg_percent  field_goals  \
# 3901          344.0  ...       0.361667    136.0    0.395000        320.0
# 3902          188.0  ...            NaN      0.0    0.405000        244.0
# 3903            3.0  ...       1.000000      1.0    0.167000          1.0
# 3904            0.0  ...            NaN      0.0         NaN          0.0
# 3905           51.0  ...       0.300000      3.0    0.408000         51.0
# 3906          666.0  ...       0.372333    300.0    0.444333       1045.0
# 3907         2025.0  ...       0.219824    180.0    0.469167       7490.0
# 3908          648.0  ...            NaN      0.0    0.399500       1936.0
# 3909          213.0  ...       0.000000      0.0    0.481375        679.0
# 3910          110.0  ...       0.290000     37.0    0.467000        320.0
# 3911           10.0  ...       0.000000      0.0    0.342000         27.0
# 3912         1233.0  ...       0.000000      0.0    0.464429       2374.0
# 3913            3.0  ...            NaN      0.0    0.250000          5.0
# 3914          217.0  ...            NaN      0.0    0.370333        396.0
# 3915           94.0  ...            NaN      0.0    0.505429        522.0
# 3916          839.0  ...            NaN      0.0    0.463500       3396.0
# 3917           33.0  ...            NaN      0.0    0.370125        183.0
# 3918           10.0  ...       0.182333      6.0    0.342000         22.0
# 3919          165.0  ...       0.296000     37.0    0.406667        197.0
# 3920          955.0  ...       0.140417     31.0    0.478385       4207.0
#
#       shooting_percent  player_efficiency_rating  games_played  seasons  \
# 3901          0.518667                 11.233333          92.0        3
# 3902          0.445667                 10.400000         118.0        3
# 3903          0.451000                 15.600000           4.0        1
# 3904          1.136000                 12.800000           1.0        1
# 3905          0.457000                 11.700000          24.0        1
# 3906          0.546333                 13.400000         206.0        3
# 3907          0.519444                 19.216667        1107.0       18
# 3908          0.450071                 13.750000         570.0       14
# 3909          0.499750                 11.125000         304.0        8
# 3910          0.539000                 16.820000         190.0        5
# 3911          0.406000                  4.300000          28.0        1
# 3912          0.535286                 14.042857         961.0       14
# 3913          0.250000                 -4.400000          12.0        2
# 3914          0.464333                 14.400000         179.0        3
# 3915          0.558143                 12.728571         239.0        7
# 3916          0.525000                 16.462500         570.0        8
# 3917          0.493375                 13.400000         146.0        8
# 3918          0.412667                  8.433333          32.0        3
# 3919          0.492000                  9.800000         148.0        3
# 3920          0.531308                 17.769231         843.0       13
#
#       position  team
# 3901        PF   NYK
# 3902        SF   MIL
# 3903        PF   NYK
# 3904        PF   GSW
# 3905        PG   BUF
# 3906         C   BOS
# 3907        PF   MIL
# 3908        SF   KCO
# 3909        SF   GSW
# 3910         C   PHI
# 3911        SF   PHO
# 3912         C   BOS
# 3913        SG   DET
# 3914        SF   CLE
# 3915         C   SEA
# 3916        PG   NYK
# 3917        SF   PHI
# 3918        SG   POR
# 3919        SG   TOT
# 3920        SG   NYK
#
# [20 rows x 27 columns]

# %%
totals['mvp'].value_counts()
# Out:
# 0    3889
# 1      19
# 2       5
# 3       3
# 4       2
# 5       2
# 6       1
# Name: mvp, dtype: int64

# %%
totals['total_rings'].value_counts()
# Out:
# 0     3318
# 1      433
# 2       91
# 3       40
# 4       15
# 5       11
# 6        4
# 8        4
# 7        3
# 10       1
# 11       1
# Name: total_rings, dtype: int64

# %%
hall_of_fame
# Out:
#                     total_points  total_personal_fouls  total_turnovers  \
# player
# A.C. Green               12928.0                2581.0           1508.0
# A.J. Price                1656.0                 252.0            243.0
# Aaron Brooks              7839.0                1544.0           1272.0
# Aaron Gordon              1981.0                 408.0            193.0
# Aaron Gray                1235.0                 796.0            314.0
# ...                          ...                   ...              ...
# Zaza Pachulia             6774.0                2465.0           1316.0
# Zeke Zawoluk              1210.0                 450.0              0.0
# Zeljko Rebraca            1367.0                 564.0            220.0
# Zelmo Beaty*              9107.0                2132.0              0.0
# Zydrunas Ilgauskas       10976.0                2776.0           1509.0
#
#                     total_blocks  total_steals  total_assists  total_rebounds  \
# player
# A.C. Green                 562.0        1103.0         1469.0         10129.0
# A.J. Price                   9.0         132.0          613.0           409.0
# Aaron Brooks               113.0         469.0         2485.0          1360.0
# Aaron Gordon               117.0         144.0          311.0          1081.0
# Aaron Gray                 106.0         113.0          251.0          1407.0
# ...                          ...           ...            ...             ...
# Zaza Pachulia              344.0         699.0         1233.0          5729.0
# Zeke Zawoluk                 0.0           0.0          217.0           732.0
# Zeljko Rebraca             171.0          62.0           94.0           746.0
# Zelmo Beaty*                29.0          45.0          839.0          5949.0
# Zydrunas Ilgauskas        1327.0         421.0          955.0          6191.0
#
#                     defensive_rebounds  offensive_rebounds  ft_percentage  \
# player
# A.C. Green                      6553.0              3576.0       0.708056
# A.J. Price                       335.0                74.0       0.632250
# Aaron Brooks                    1037.0               323.0       0.838000
# Aaron Gordon                     765.0               316.0       0.702667
# Aaron Gray                       889.0               518.0       0.560000
# ...                                ...                 ...            ...
# Zaza Pachulia                   3555.0              2174.0       0.743429
# Zeke Zawoluk                       0.0                 0.0       0.750667
# Zeljko Rebraca                   527.0               219.0       0.747286
# Zelmo Beaty*                     234.0                93.0       0.751750
# Zydrunas Ilgauskas              3747.0              2444.0       0.760692
#
#                     ...  3p_made  fg_percent  field_goals  shooting_percent  \
# player              ...
# A.C. Green          ...    125.0    0.487667       4778.0          0.543556
# A.J. Price          ...    233.0    0.355222        600.0          0.435000
# Aaron Brooks        ...   1025.0    0.403133       2829.0          0.512267
# Aaron Gordon        ...    132.0    0.458000        760.0          0.529333
# Aaron Gray          ...      0.0    0.508727        509.0          0.525000
# ...                 ...      ...         ...          ...               ...
# Zaza Pachulia       ...      0.0    0.464429       2374.0          0.535286
# Zeke Zawoluk        ...      0.0    0.370333        396.0          0.464333
# Zeljko Rebraca      ...      0.0    0.505429        522.0          0.558143
# Zelmo Beaty*        ...      0.0    0.463500       3396.0          0.525000
# Zydrunas Ilgauskas  ...     31.0    0.478385       4207.0          0.531308
#
#                     player_efficiency_rating  games_played  seasons  position  \
# player
# A.C. Green                         13.872222        1361.0       18       G-F
# A.J. Price                         10.388889         287.0        9         F
# Aaron Brooks                       12.326667         797.0       15       F-C
# Aaron Gordon                       14.266667         205.0        3       F-C
# Aaron Gray                         10.900000         387.0       11       F-C
# ...                                      ...           ...      ...       ...
# Zaza Pachulia                      14.042857         961.0       14         C
# Zeke Zawoluk                       14.400000         179.0        3        SF
# Zeljko Rebraca                     12.728571         239.0        7         C
# Zelmo Beaty*                       16.462500         570.0        8        PG
# Zydrunas Ilgauskas                 17.769231         843.0       13        SG
#
#                     team  HOF
# player
# A.C. Green           FTW    0
# A.J. Price           NYK    0
# Aaron Brooks         TOT    0
# Aaron Gordon         FTW    0
# Aaron Gray           AND    0
# ...                  ...  ...
# Zaza Pachulia        BOS    0
# Zeke Zawoluk         CLE    0
# Zeljko Rebraca       SEA    0
# Zelmo Beaty*         NYK    1
# Zydrunas Ilgauskas   NYK    0
#
# [1968 rows x 24 columns]

# %%
hall_of_fame['team'].value_counts()
# Out:
# NYK    176
# TOT    172
# BOS    147
# CIN    104
# DET    102
# PHW     90
# STL     86
# SYR     83
# PHI     80
# LAL     77
# MNL     70
# SFW     67
# BAL     62
# FTW     51
# SEA     50
# BLB     45
# CHI     44
# ROC     42
# MIL     39
# PHO     36
# CLE     32
# MLH     32
# ATL     32
# POR     27
# INO     24
# SDR     21
# TRI     21
# BUF     20
# WSC     17
# HOU     15
# GSW     13
# WAT     12
# AND     11
# KCO     10
# SHE      9
# CHS      8
# STB      7
# CHP      7
# DNN      6
# CHZ      6
# CAP      2
# Name: team, dtype: int64
